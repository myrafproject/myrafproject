# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Header
#
# Simular to `Fits`, `FitsArray` object has 3 methods to deal with header:
#
# - `header`: Returns the header as a `pandas.DataFrame`.
# - `pure_header`: Returns the header as an `astropy.io.fits.header.Header`.
# - `hedit`: Modifies the header.
#
# ## header

# %%
from myraflib import FitsArray

fits_array = FitsArray.sample()
fits_array.header()
# Out:
#                           SIMPLE  BITPIX  NAXIS  NAXIS1  NAXIS2  WCSAXES  \
# image
# /tmp/myraf_5v4rna9n.fits    True      16      2     891     893        2
# /tmp/myraf_v3lehplm.fits    True      16      2     891     893        2
# /tmp/myraf_jnno4_fq.fits    True      16      2     891     893        2
# /tmp/myraf_6fae21sn.fits    True      16      2     891     893        2
# /tmp/myraf_vq9i8kb_.fits    True      16      2     891     893        2
# /tmp/myraf_e2lwd9yb.fits    True      16      2     891     893        2
# /tmp/myraf_7fphqukx.fits    True      16      2     891     893        2
# /tmp/myraf_ayewodbr.fits    True      16      2     891     893        2
# /tmp/myraf_o0seuucc.fits    True      16      2     891     893        2
# /tmp/myraf_k45oeo_8.fits    True      16      2     891     893        2
#
#                               CRPIX1      CRPIX2    PC1_1         PC1_2  ...  \
# image                                                                    ...
# /tmp/myraf_5v4rna9n.fits  470.646197  440.615706 -0.00028  2.836620e-07  ...
# /tmp/myraf_v3lehplm.fits  440.733012  448.400807 -0.00028  2.832374e-07  ...
# /tmp/myraf_jnno4_fq.fits  465.465897  463.441110 -0.00028  2.855669e-07  ...
# /tmp/myraf_6fae21sn.fits  470.458965  454.412646 -0.00028  2.868561e-07  ...
# /tmp/myraf_vq9i8kb_.fits  452.556018  483.117870 -0.00028  2.828607e-07  ...
# /tmp/myraf_e2lwd9yb.fits  479.047064  479.613825 -0.00028  2.828539e-07  ...
# /tmp/myraf_7fphqukx.fits  500.346234  477.437107 -0.00028  2.826619e-07  ...
# /tmp/myraf_ayewodbr.fits  491.420357  497.302152 -0.00028  2.819173e-07  ...
# /tmp/myraf_o0seuucc.fits  530.291964  542.619263 -0.00028  2.853185e-07  ...
# /tmp/myraf_k45oeo_8.fits  559.129559  528.002320 -0.00028  2.865583e-07  ...
#
#                             CTYPE1    CTYPE2     CRVAL1    CRVAL2 LONPOLE  \
# image
# /tmp/myraf_5v4rna9n.fits  RA---TAN  DEC--TAN  85.268078 -2.460074   180.0
# /tmp/myraf_v3lehplm.fits  RA---TAN  DEC--TAN  85.279274 -2.460706   180.0
# /tmp/myraf_jnno4_fq.fits  RA---TAN  DEC--TAN  85.275143 -2.459291   180.0
# /tmp/myraf_6fae21sn.fits  RA---TAN  DEC--TAN  85.276542 -2.464616   180.0
# /tmp/myraf_vq9i8kb_.fits  RA---TAN  DEC--TAN  85.284375 -2.459392   180.0
# /tmp/myraf_e2lwd9yb.fits  RA---TAN  DEC--TAN  85.279745 -2.463166   180.0
# /tmp/myraf_7fphqukx.fits  RA---TAN  DEC--TAN  85.276572 -2.466569   180.0
# /tmp/myraf_ayewodbr.fits  RA---TAN  DEC--TAN  85.281884 -2.463815   180.0
# /tmp/myraf_o0seuucc.fits  RA---TAN  DEC--TAN  85.273794 -2.453924   180.0
# /tmp/myraf_k45oeo_8.fits  RA---TAN  DEC--TAN  85.268503 -2.460805   180.0
#
#                            LATPOLE MJDREF RADESYS  BSCALE  BZERO
# image
# /tmp/myraf_5v4rna9n.fits -2.460074    0.0    ICRS       1  32768
# /tmp/myraf_v3lehplm.fits -2.460706    0.0    ICRS       1  32768
# /tmp/myraf_jnno4_fq.fits -2.459291    0.0    ICRS       1  32768
# /tmp/myraf_6fae21sn.fits -2.464616    0.0    ICRS       1  32768
# /tmp/myraf_vq9i8kb_.fits -2.459392    0.0    ICRS       1  32768
# /tmp/myraf_e2lwd9yb.fits -2.463166    0.0    ICRS       1  32768
# /tmp/myraf_7fphqukx.fits -2.466569    0.0    ICRS       1  32768
# /tmp/myraf_ayewodbr.fits -2.463815    0.0    ICRS       1  32768
# /tmp/myraf_o0seuucc.fits -2.453924    0.0    ICRS       1  32768
# /tmp/myraf_k45oeo_8.fits -2.460805    0.0    ICRS       1  32768
#
# [10 rows x 26 columns]

# %% [markdown]
# ## pure_header

# %%
fits_array.pure_header()
# Out:
# [SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      470.64619731851 / Pixel coordinate of reference point
#  CRPIX2  =      440.61570551996 / Pixel coordinate of reference point
#  PC1_1   = -0.00028027970892709 / Coordinate transformation matrix element
#  PC1_2   =  2.8366202256661E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1630992908483E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979588943844 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.268078127742 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4600737557032 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4600737557032 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =       440.7330120185 / Pixel coordinate of reference point
#  CRPIX2  =      448.40080690483 / Pixel coordinate of reference point
#  PC1_1   = -0.00028027960272444 / Coordinate transformation matrix element
#  PC1_2   =  2.8323741978055E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1204270335114E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979747192257 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.279274228757 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4607060329218 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4607060329218 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      465.46589735708 / Pixel coordinate of reference point
#  CRPIX2  =       463.4411095065 / Pixel coordinate of reference point
#  PC1_1   = -0.00028028266175372 / Coordinate transformation matrix element
#  PC1_2   =  2.8556693407892E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1352312163875E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979462262095 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.275143055852 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4592907374664 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4592907374664 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      470.45896477767 / Pixel coordinate of reference point
#  CRPIX2  =      454.41264577131 / Pixel coordinate of reference point
#  PC1_1   = -0.00028027983086788 / Coordinate transformation matrix element
#  PC1_2   =  2.8685609840454E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1188148348334E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979557692726 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.276541576304 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4646164249836 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4646164249836 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      452.55601799972 / Pixel coordinate of reference point
#  CRPIX2  =      483.11786979888 / Pixel coordinate of reference point
#  PC1_1   = -0.00028028111742717 / Coordinate transformation matrix element
#  PC1_2   =  2.8286069427751E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.0969681894597E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979606092431 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.284375233855 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4593919628165 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4593919628165 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      479.04706368746 / Pixel coordinate of reference point
#  CRPIX2  =      479.61382518798 / Pixel coordinate of reference point
#  PC1_1   = -0.00028028056438264 / Coordinate transformation matrix element
#  PC1_2   =  2.8285391189857E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1315282982005E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979651093775 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =       85.27974531743 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4631656202134 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4631656202134 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      500.34623442173 / Pixel coordinate of reference point
#  CRPIX2  =      477.43710652612 / Pixel coordinate of reference point
#  PC1_1   = -0.00028028130965513 / Coordinate transformation matrix element
#  PC1_2   =  2.8266188975304E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1346785352493E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979600747194 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.276571838314 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4665690046187 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4665690046187 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =       491.4203571568 / Pixel coordinate of reference point
#  CRPIX2  =      497.30215246684 / Pixel coordinate of reference point
#  PC1_1   = -0.00028028176560488 / Coordinate transformation matrix element
#  PC1_2   =  2.8191734340905E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1252144548217E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979513247401 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.281883874941 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4638150656279 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4638150656279 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      530.29196426975 / Pixel coordinate of reference point
#  CRPIX2  =       542.6192630202 / Pixel coordinate of reference point
#  PC1_1   = -0.00028028030754274 / Coordinate transformation matrix element
#  PC1_2   =   2.853184584587E-07 / Coordinate transformation matrix element
#  PC2_1   =  3.1562749784065E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979521084279 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.273794308229 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4539238874175 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4539238874175 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ,
#  SIMPLE  =                    T / conforms to FITS standard
#  BITPIX  =                   16 / array data type
#  NAXIS   =                    2 / number of array dimensions
#  NAXIS1  =                  891
#  NAXIS2  =                  893
#  WCSAXES =                    2 / Number of coordinate axes
#  CRPIX1  =      559.12955916691 / Pixel coordinate of reference point
#  CRPIX2  =       528.0023198582 / Pixel coordinate of reference point
#  PC1_1   = -0.00028028277289376 / Coordinate transformation matrix element
#  PC1_2   =  2.8655828251197E-07 / Coordinate transformation matrix element
#  PC2_1   =   3.163262306985E-07 / Coordinate transformation matrix element
#  PC2_2   =  0.00027979634526848 / Coordinate transformation matrix element
#  CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
#  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
#  CUNIT1  = 'deg'                / Units of coordinate increment and value
#  CUNIT2  = 'deg'                / Units of coordinate increment and value
#  CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
#  CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
#  CRVAL1  =      85.268502978382 / [deg] Coordinate value at reference point
#  CRVAL2  =     -2.4608052800754 / [deg] Coordinate value at reference point
#  LONPOLE =                180.0 / [deg] Native longitude of celestial pole
#  LATPOLE =     -2.4608052800754 / [deg] Native latitude of celestial pole
#  MJDREF  =                  0.0 / [d] MJD of fiducial time
#  RADESYS = 'ICRS'               / Equatorial coordinate system
#  BSCALE  =                    1
#  BZERO   =                32768                                                  ]

# %% [markdown]
# ## hedit
#
# The `hedit` method simplifies the process of modifying FITS headers, encompassing creation, updating, and deletion of header entries:
#
# - To **add** a new key-value pair to the header, provide a key that does not already exist in the header.
# - To **update** the value of an existing key, provide a key that is already present in the header.
# - To **delete** a key, use the key to remove the corresponding entry from the header.
#
# ### Create

# %%
fits_array.hedit("test", "MYRaf", "Created by MYRaf") 
fits_array.header()
# Out:
#                           SIMPLE  BITPIX  NAXIS  NAXIS1  NAXIS2  WCSAXES  \
# image
# /tmp/myraf_5v4rna9n.fits    True      16      2     891     893        2
# /tmp/myraf_v3lehplm.fits    True      16      2     891     893        2
# /tmp/myraf_jnno4_fq.fits    True      16      2     891     893        2
# /tmp/myraf_6fae21sn.fits    True      16      2     891     893        2
# /tmp/myraf_vq9i8kb_.fits    True      16      2     891     893        2
# /tmp/myraf_e2lwd9yb.fits    True      16      2     891     893        2
# /tmp/myraf_7fphqukx.fits    True      16      2     891     893        2
# /tmp/myraf_ayewodbr.fits    True      16      2     891     893        2
# /tmp/myraf_o0seuucc.fits    True      16      2     891     893        2
# /tmp/myraf_k45oeo_8.fits    True      16      2     891     893        2
#
#                               CRPIX1      CRPIX2    PC1_1         PC1_2  ...  \
# image                                                                    ...
# /tmp/myraf_5v4rna9n.fits  470.646197  440.615706 -0.00028  2.836620e-07  ...
# /tmp/myraf_v3lehplm.fits  440.733012  448.400807 -0.00028  2.832374e-07  ...
# /tmp/myraf_jnno4_fq.fits  465.465897  463.441110 -0.00028  2.855669e-07  ...
# /tmp/myraf_6fae21sn.fits  470.458965  454.412646 -0.00028  2.868561e-07  ...
# /tmp/myraf_vq9i8kb_.fits  452.556018  483.117870 -0.00028  2.828607e-07  ...
# /tmp/myraf_e2lwd9yb.fits  479.047064  479.613825 -0.00028  2.828539e-07  ...
# /tmp/myraf_7fphqukx.fits  500.346234  477.437107 -0.00028  2.826619e-07  ...
# /tmp/myraf_ayewodbr.fits  491.420357  497.302152 -0.00028  2.819173e-07  ...
# /tmp/myraf_o0seuucc.fits  530.291964  542.619263 -0.00028  2.853185e-07  ...
# /tmp/myraf_k45oeo_8.fits  559.129559  528.002320 -0.00028  2.865583e-07  ...
#
#                             CTYPE2     CRVAL1    CRVAL2  LONPOLE   LATPOLE  \
# image
# /tmp/myraf_5v4rna9n.fits  DEC--TAN  85.268078 -2.460074    180.0 -2.460074
# /tmp/myraf_v3lehplm.fits  DEC--TAN  85.279274 -2.460706    180.0 -2.460706
# /tmp/myraf_jnno4_fq.fits  DEC--TAN  85.275143 -2.459291    180.0 -2.459291
# /tmp/myraf_6fae21sn.fits  DEC--TAN  85.276542 -2.464616    180.0 -2.464616
# /tmp/myraf_vq9i8kb_.fits  DEC--TAN  85.284375 -2.459392    180.0 -2.459392
# /tmp/myraf_e2lwd9yb.fits  DEC--TAN  85.279745 -2.463166    180.0 -2.463166
# /tmp/myraf_7fphqukx.fits  DEC--TAN  85.276572 -2.466569    180.0 -2.466569
# /tmp/myraf_ayewodbr.fits  DEC--TAN  85.281884 -2.463815    180.0 -2.463815
# /tmp/myraf_o0seuucc.fits  DEC--TAN  85.273794 -2.453924    180.0 -2.453924
# /tmp/myraf_k45oeo_8.fits  DEC--TAN  85.268503 -2.460805    180.0 -2.460805
#
#                          MJDREF RADESYS BSCALE  BZERO   TEST
# image
# /tmp/myraf_5v4rna9n.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_v3lehplm.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_jnno4_fq.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_6fae21sn.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_vq9i8kb_.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_e2lwd9yb.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_7fphqukx.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_ayewodbr.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_o0seuucc.fits    0.0    ICRS      1  32768  MYRaf
# /tmp/myraf_k45oeo_8.fits    0.0    ICRS      1  32768  MYRaf
#
# [10 rows x 27 columns]

# %% [markdown]
# Here `test` is the key, `MYRaf` is the value and `Created by MYRaf` is the comment.

# %% [markdown]
# `hedit` can add multiple headers at once.

# %%
fits_array.hedit(["test", "test1", "test2", "test3"], ["MYRaf V 3", "MYRaf 1", "MYRaf 2", "MYRaf 3"], ["Created by MYRaf", "Created by MYRaf"]) 
fits_array.header()
# Out:
#                           SIMPLE  BITPIX  NAXIS  NAXIS1  NAXIS2  WCSAXES  \
# image
# /tmp/myraf_5v4rna9n.fits    True      16      2     891     893        2
# /tmp/myraf_v3lehplm.fits    True      16      2     891     893        2
# /tmp/myraf_jnno4_fq.fits    True      16      2     891     893        2
# /tmp/myraf_6fae21sn.fits    True      16      2     891     893        2
# /tmp/myraf_vq9i8kb_.fits    True      16      2     891     893        2
# /tmp/myraf_e2lwd9yb.fits    True      16      2     891     893        2
# /tmp/myraf_7fphqukx.fits    True      16      2     891     893        2
# /tmp/myraf_ayewodbr.fits    True      16      2     891     893        2
# /tmp/myraf_o0seuucc.fits    True      16      2     891     893        2
# /tmp/myraf_k45oeo_8.fits    True      16      2     891     893        2
#
#                               CRPIX1      CRPIX2    PC1_1         PC1_2  ...  \
# image                                                                    ...
# /tmp/myraf_5v4rna9n.fits  470.646197  440.615706 -0.00028  2.836620e-07  ...
# /tmp/myraf_v3lehplm.fits  440.733012  448.400807 -0.00028  2.832374e-07  ...
# /tmp/myraf_jnno4_fq.fits  465.465897  463.441110 -0.00028  2.855669e-07  ...
# /tmp/myraf_6fae21sn.fits  470.458965  454.412646 -0.00028  2.868561e-07  ...
# /tmp/myraf_vq9i8kb_.fits  452.556018  483.117870 -0.00028  2.828607e-07  ...
# /tmp/myraf_e2lwd9yb.fits  479.047064  479.613825 -0.00028  2.828539e-07  ...
# /tmp/myraf_7fphqukx.fits  500.346234  477.437107 -0.00028  2.826619e-07  ...
# /tmp/myraf_ayewodbr.fits  491.420357  497.302152 -0.00028  2.819173e-07  ...
# /tmp/myraf_o0seuucc.fits  530.291964  542.619263 -0.00028  2.853185e-07  ...
# /tmp/myraf_k45oeo_8.fits  559.129559  528.002320 -0.00028  2.865583e-07  ...
#
#                           LONPOLE   LATPOLE  MJDREF  RADESYS BSCALE  BZERO  \
# image
# /tmp/myraf_5v4rna9n.fits    180.0 -2.460074     0.0     ICRS      1  32768
# /tmp/myraf_v3lehplm.fits    180.0 -2.460706     0.0     ICRS      1  32768
# /tmp/myraf_jnno4_fq.fits    180.0 -2.459291     0.0     ICRS      1  32768
# /tmp/myraf_6fae21sn.fits    180.0 -2.464616     0.0     ICRS      1  32768
# /tmp/myraf_vq9i8kb_.fits    180.0 -2.459392     0.0     ICRS      1  32768
# /tmp/myraf_e2lwd9yb.fits    180.0 -2.463166     0.0     ICRS      1  32768
# /tmp/myraf_7fphqukx.fits    180.0 -2.466569     0.0     ICRS      1  32768
# /tmp/myraf_ayewodbr.fits    180.0 -2.463815     0.0     ICRS      1  32768
# /tmp/myraf_o0seuucc.fits    180.0 -2.453924     0.0     ICRS      1  32768
# /tmp/myraf_k45oeo_8.fits    180.0 -2.460805     0.0     ICRS      1  32768
#
#                                TEST    TEST1    TEST2    TEST3
# image
# /tmp/myraf_5v4rna9n.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_v3lehplm.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_jnno4_fq.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_6fae21sn.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_vq9i8kb_.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_e2lwd9yb.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_7fphqukx.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_ayewodbr.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_o0seuucc.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
# /tmp/myraf_k45oeo_8.fits  MYRaf V 3  MYRaf 1  MYRaf 2  MYRaf 3
#
# [10 rows x 30 columns]

# %% [markdown]
# Please notice that the number of comments are not equal to number of key-value pairs. That was intentional.

# %% [markdown]
# ### value_is_key
#
# This optional parameter for `hedit` functions as a flag to specify that the provided value should be treated as a key in the header. If set, the value associated with this key will be used to populate the target key.

# %%
fits_array.hedit("test3", "NAXIS", "Brought from NAXIS", value_is_key=True)
fits_array.header()
# Out:
#                           SIMPLE  BITPIX  NAXIS  NAXIS1  NAXIS2  WCSAXES  \
# image
# /tmp/myraf_5v4rna9n.fits    True      16      2     891     893        2
# /tmp/myraf_v3lehplm.fits    True      16      2     891     893        2
# /tmp/myraf_jnno4_fq.fits    True      16      2     891     893        2
# /tmp/myraf_6fae21sn.fits    True      16      2     891     893        2
# /tmp/myraf_vq9i8kb_.fits    True      16      2     891     893        2
# /tmp/myraf_e2lwd9yb.fits    True      16      2     891     893        2
# /tmp/myraf_7fphqukx.fits    True      16      2     891     893        2
# /tmp/myraf_ayewodbr.fits    True      16      2     891     893        2
# /tmp/myraf_o0seuucc.fits    True      16      2     891     893        2
# /tmp/myraf_k45oeo_8.fits    True      16      2     891     893        2
#
#                               CRPIX1      CRPIX2    PC1_1         PC1_2  ...  \
# image                                                                    ...
# /tmp/myraf_5v4rna9n.fits  470.646197  440.615706 -0.00028  2.836620e-07  ...
# /tmp/myraf_v3lehplm.fits  440.733012  448.400807 -0.00028  2.832374e-07  ...
# /tmp/myraf_jnno4_fq.fits  465.465897  463.441110 -0.00028  2.855669e-07  ...
# /tmp/myraf_6fae21sn.fits  470.458965  454.412646 -0.00028  2.868561e-07  ...
# /tmp/myraf_vq9i8kb_.fits  452.556018  483.117870 -0.00028  2.828607e-07  ...
# /tmp/myraf_e2lwd9yb.fits  479.047064  479.613825 -0.00028  2.828539e-07  ...
# /tmp/myraf_7fphqukx.fits  500.346234  477.437107 -0.00028  2.826619e-07  ...
# /tmp/myraf_ayewodbr.fits  491.420357  497.302152 -0.00028  2.819173e-07  ...
# /tmp/myraf_o0seuucc.fits  530.291964  542.619263 -0.00028  2.853185e-07  ...
# /tmp/myraf_k45oeo_8.fits  559.129559  528.002320 -0.00028  2.865583e-07  ...
#
#                           LONPOLE   LATPOLE  MJDREF  RADESYS BSCALE  BZERO  \
# image
# /tmp/myraf_5v4rna9n.fits    180.0 -2.460074     0.0     ICRS      1  32768
# /tmp/myraf_v3lehplm.fits    180.0 -2.460706     0.0     ICRS      1  32768
# /tmp/myraf_jnno4_fq.fits    180.0 -2.459291     0.0     ICRS      1  32768
# /tmp/myraf_6fae21sn.fits    180.0 -2.464616     0.0     ICRS      1  32768
# /tmp/myraf_vq9i8kb_.fits    180.0 -2.459392     0.0     ICRS      1  32768
# /tmp/myraf_e2lwd9yb.fits    180.0 -2.463166     0.0     ICRS      1  32768
# /tmp/myraf_7fphqukx.fits    180.0 -2.466569     0.0     ICRS      1  32768
# /tmp/myraf_ayewodbr.fits    180.0 -2.463815     0.0     ICRS      1  32768
# /tmp/myraf_o0seuucc.fits    180.0 -2.453924     0.0     ICRS      1  32768
# /tmp/myraf_k45oeo_8.fits    180.0 -2.460805     0.0     ICRS      1  32768
#
#                                TEST    TEST1    TEST2  TEST3
# image
# /tmp/myraf_5v4rna9n.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_v3lehplm.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_jnno4_fq.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_6fae21sn.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_vq9i8kb_.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_e2lwd9yb.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_7fphqukx.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_ayewodbr.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_o0seuucc.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
# /tmp/myraf_k45oeo_8.fits  MYRaf V 3  MYRaf 1  MYRaf 2      2
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Delete
#
# Similar to `value_is_key`, the `delete` parameter acts as a flag. When enabled, the method will ignore all other checks and solely focus on identifying and deleting the specified key(s).

# %%
fits_array.hedit(["test", "test1", "test2", "test3"], delete=True)
fits_array.header()
# Out:
#                           SIMPLE  BITPIX  NAXIS  NAXIS1  NAXIS2  WCSAXES  \
# image
# /tmp/myraf_5v4rna9n.fits    True      16      2     891     893        2
# /tmp/myraf_v3lehplm.fits    True      16      2     891     893        2
# /tmp/myraf_jnno4_fq.fits    True      16      2     891     893        2
# /tmp/myraf_6fae21sn.fits    True      16      2     891     893        2
# /tmp/myraf_vq9i8kb_.fits    True      16      2     891     893        2
# /tmp/myraf_e2lwd9yb.fits    True      16      2     891     893        2
# /tmp/myraf_7fphqukx.fits    True      16      2     891     893        2
# /tmp/myraf_ayewodbr.fits    True      16      2     891     893        2
# /tmp/myraf_o0seuucc.fits    True      16      2     891     893        2
# /tmp/myraf_k45oeo_8.fits    True      16      2     891     893        2
#
#                               CRPIX1      CRPIX2    PC1_1         PC1_2  ...  \
# image                                                                    ...
# /tmp/myraf_5v4rna9n.fits  470.646197  440.615706 -0.00028  2.836620e-07  ...
# /tmp/myraf_v3lehplm.fits  440.733012  448.400807 -0.00028  2.832374e-07  ...
# /tmp/myraf_jnno4_fq.fits  465.465897  463.441110 -0.00028  2.855669e-07  ...
# /tmp/myraf_6fae21sn.fits  470.458965  454.412646 -0.00028  2.868561e-07  ...
# /tmp/myraf_vq9i8kb_.fits  452.556018  483.117870 -0.00028  2.828607e-07  ...
# /tmp/myraf_e2lwd9yb.fits  479.047064  479.613825 -0.00028  2.828539e-07  ...
# /tmp/myraf_7fphqukx.fits  500.346234  477.437107 -0.00028  2.826619e-07  ...
# /tmp/myraf_ayewodbr.fits  491.420357  497.302152 -0.00028  2.819173e-07  ...
# /tmp/myraf_o0seuucc.fits  530.291964  542.619263 -0.00028  2.853185e-07  ...
# /tmp/myraf_k45oeo_8.fits  559.129559  528.002320 -0.00028  2.865583e-07  ...
#
#                             CTYPE1    CTYPE2     CRVAL1    CRVAL2 LONPOLE  \
# image
# /tmp/myraf_5v4rna9n.fits  RA---TAN  DEC--TAN  85.268078 -2.460074   180.0
# /tmp/myraf_v3lehplm.fits  RA---TAN  DEC--TAN  85.279274 -2.460706   180.0
# /tmp/myraf_jnno4_fq.fits  RA---TAN  DEC--TAN  85.275143 -2.459291   180.0
# /tmp/myraf_6fae21sn.fits  RA---TAN  DEC--TAN  85.276542 -2.464616   180.0
# /tmp/myraf_vq9i8kb_.fits  RA---TAN  DEC--TAN  85.284375 -2.459392   180.0
# /tmp/myraf_e2lwd9yb.fits  RA---TAN  DEC--TAN  85.279745 -2.463166   180.0
# /tmp/myraf_7fphqukx.fits  RA---TAN  DEC--TAN  85.276572 -2.466569   180.0
# /tmp/myraf_ayewodbr.fits  RA---TAN  DEC--TAN  85.281884 -2.463815   180.0
# /tmp/myraf_o0seuucc.fits  RA---TAN  DEC--TAN  85.273794 -2.453924   180.0
# /tmp/myraf_k45oeo_8.fits  RA---TAN  DEC--TAN  85.268503 -2.460805   180.0
#
#                            LATPOLE MJDREF RADESYS  BSCALE  BZERO
# image
# /tmp/myraf_5v4rna9n.fits -2.460074    0.0    ICRS       1  32768
# /tmp/myraf_v3lehplm.fits -2.460706    0.0    ICRS       1  32768
# /tmp/myraf_jnno4_fq.fits -2.459291    0.0    ICRS       1  32768
# /tmp/myraf_6fae21sn.fits -2.464616    0.0    ICRS       1  32768
# /tmp/myraf_vq9i8kb_.fits -2.459392    0.0    ICRS       1  32768
# /tmp/myraf_e2lwd9yb.fits -2.463166    0.0    ICRS       1  32768
# /tmp/myraf_7fphqukx.fits -2.466569    0.0    ICRS       1  32768
# /tmp/myraf_ayewodbr.fits -2.463815    0.0    ICRS       1  32768
# /tmp/myraf_o0seuucc.fits -2.453924    0.0    ICRS       1  32768
# /tmp/myraf_k45oeo_8.fits -2.460805    0.0    ICRS       1  32768
#
# [10 rows x 26 columns]
