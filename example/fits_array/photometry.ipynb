# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Photometry
#
# Photometry is the primary purpose of MYRaf. The software provides two methods for performing photometric analysis:

# %%
from myraflib import FitsArray

fits_array = FitsArray.sample()

sources = fits_array.extract()
sources
# Out:
#           thresh  npix  tnpix  xmin  xmax  ymin  ymax   xcentroid   ycentroid  \
# 0    2917.966797     5      5   460   461   507   509  460.413271  507.778814
# 1    2917.966797     5      5   386   388   127   128  386.810402  127.389405
# 2    2917.966797     5      5   524   526   138   139  525.221542  138.399809
# 3    2917.966797     6      6   859   860   753   755  859.504395  753.975957
# 4    2917.966797     6      6   560   561   865   867  560.489036  865.999199
# ..           ...   ...    ...   ...   ...   ...   ...         ...         ...
# 151  2917.966797   289    276   264   291   189   214  276.691617  199.843224
# 152  2917.966797   558    528   158   185   723   759  170.623468  737.848725
# 153  2917.966797   816    793   498   526   504   547  513.939993  525.358671
# 154  2917.966797  2464   2386   610   674   360   504  646.761183  430.331463
# 155  2917.966797  5533   5293   406   609   278   361  482.341496  319.878004
#
#               x2  ...       cxy         cflux          flux         cpeak  \
# 0       0.242478  ...  1.951457  1.603632e+04  1.802740e+04   3322.732910
# 1       0.534022  ...  1.903618  1.721474e+04  2.111875e+04   3854.528564
# 2       0.530407  ... -1.885721  1.741779e+04  2.194193e+04   3799.070068
# 3       0.249981  ... -0.013324  2.018741e+04  2.380344e+04   3868.737549
# 4       0.249880  ...  0.102132  2.138295e+04  2.433334e+04   3906.162598
# ..           ...  ...       ...           ...           ...           ...
# 151    19.669842  ... -0.003841  2.409867e+06  2.447779e+06  13457.583984
# 152    24.997992  ... -0.004552  3.524505e+06  3.542909e+06  15404.105469
# 153    35.996675  ...  0.012305  3.601250e+06  3.630857e+06   6325.308105
# 154   133.532700  ... -0.014738  1.089770e+07  1.102320e+07   7858.287109
# 155  1797.977936  ... -0.002504  2.259929e+07  2.278125e+07   6972.029297
#
#              peak  xcpeak  ycpeak  xpeak  ypeak  flag
# 0     3845.903809     461     508    461    507     0
# 1     4915.491211     387     127    387    127     0
# 2     4864.722656     525     138    525    138     0
# 3     4960.918945     860     754    860    754     0
# 4     4663.267578     560     866    560    866     0
# ..            ...     ...     ...    ...    ...   ...
# 151  13952.725586     276     203    279    199     0
# 152  16024.943359     170     740    170    738     1
# 153   6811.786133     518     534    519    534     0
# 154   8491.102539     658     487    658    487     1
# 155   7853.476562     465     335    441    323     1
#
# [156 rows x 30 columns]

# %% [markdown]
# ## photometry_sep
#
# This method performs photometry using the `sum_circle` function.

# %%
photometry_set = fits_array.photometry_sep(sources["xcentroid"].to_list(), sources["ycentroid"].to_list(), 10)
photometry_set
# Out:
#                          package   xcentroid   ycentroid         ra       dec  \
# image
# /tmp/myraf_327ydisp.fits     sep  460.413271  507.778814  85.270688 -2.441004
# /tmp/myraf_327ydisp.fits     sep  386.810402  127.389405  85.291229 -2.547458
# /tmp/myraf_327ydisp.fits     sep  525.221542  138.399809  85.252400 -2.544334
# /tmp/myraf_327ydisp.fits     sep  859.504395  753.975957  85.158805 -2.371990
# /tmp/myraf_327ydisp.fits     sep  560.489036  865.999199  85.242717 -2.340745
# ...                          ...         ...         ...        ...       ...
# /tmp/myraf_c65fjgp8.fits     sep  276.691617  199.843224  85.347370 -2.552429
# /tmp/myraf_c65fjgp8.fits     sep  170.623468  737.848725  85.377268 -2.401929
# /tmp/myraf_c65fjgp8.fits     sep  513.939993  525.358671  85.280899 -2.461279
# /tmp/myraf_c65fjgp8.fits     sep  646.761183  430.331463  85.243610 -2.487826
# /tmp/myraf_c65fjgp8.fits     sep  482.341496  319.878004  85.289707 -2.518781
#
#                           aperture        flux     flux_error  flag  \
# image
# /tmp/myraf_327ydisp.fits        10  2650498.96  121161.453956     0
# /tmp/myraf_327ydisp.fits        10  3798401.08  213191.357561     0
# /tmp/myraf_327ydisp.fits        10  3859562.48  213931.210210     0
# /tmp/myraf_327ydisp.fits        10  3949275.84  218471.016701     0
# /tmp/myraf_327ydisp.fits        10  4654186.00  246787.566490     0
# ...                            ...         ...            ...   ...
# /tmp/myraf_c65fjgp8.fits        10  2453314.52  137667.245274     0
# /tmp/myraf_c65fjgp8.fits        10  1812507.12  108752.144328     0
# /tmp/myraf_c65fjgp8.fits        10  1886833.24  123723.651632     0
# /tmp/myraf_c65fjgp8.fits        10  3477463.32  229054.781986     0
# /tmp/myraf_c65fjgp8.fits        10  3521337.56  198364.113533     0
#
#                                  snr       mag      merr
# image
# /tmp/myraf_327ydisp.fits   66.330713  8.941681  0.049630
# /tmp/myraf_327ydisp.fits   82.351760  8.550998  0.060937
# /tmp/myraf_327ydisp.fits   75.090073  8.533655  0.060179
# /tmp/myraf_327ydisp.fits  111.505189  8.508706  0.060060
# /tmp/myraf_327ydisp.fits  108.142074  8.330391  0.057569
# ...                              ...       ...       ...
# /tmp/myraf_c65fjgp8.fits   81.115268  9.025617  0.060924
# /tmp/myraf_c65fjgp8.fits  104.442455  9.354301  0.065143
# /tmp/myraf_c65fjgp8.fits   73.603642  9.310666  0.071192
# /tmp/myraf_c65fjgp8.fits   73.311805  8.646844  0.071513
# /tmp/myraf_c65fjgp8.fits   85.519762  8.633231  0.061160
#
# [1560 rows x 12 columns]

# %% [markdown]
# ## photometry_phu
#
# This method performs photometry using the `CircularAperture` function.

# %%
photometry_phu = fits_array.photometry_phu(sources["xcentroid"].to_list(), sources["ycentroid"].to_list(), 10)
photometry_phu
# Out:
#                          package   xcentroid   ycentroid         ra       dec  \
# image
# /tmp/myraf_327ydisp.fits     phu  460.413271  507.778814  85.270688 -2.441004
# /tmp/myraf_327ydisp.fits     phu  386.810402  127.389405  85.291229 -2.547458
# /tmp/myraf_327ydisp.fits     phu  525.221542  138.399809  85.252400 -2.544334
# /tmp/myraf_327ydisp.fits     phu  859.504395  753.975957  85.158805 -2.371990
# /tmp/myraf_327ydisp.fits     phu  560.489036  865.999199  85.242717 -2.340745
# ...                          ...         ...         ...        ...       ...
# /tmp/myraf_c65fjgp8.fits     phu  276.691617  199.843224  85.347370 -2.552429
# /tmp/myraf_c65fjgp8.fits     phu  170.623468  737.848725  85.377268 -2.401929
# /tmp/myraf_c65fjgp8.fits     phu  513.939993  525.358671  85.280899 -2.461279
# /tmp/myraf_c65fjgp8.fits     phu  646.761183  430.331463  85.243610 -2.487826
# /tmp/myraf_c65fjgp8.fits     phu  482.341496  319.878004  85.289707 -2.518781
#
#                           aperture          flux     flux_error  flag  \
# image
# /tmp/myraf_327ydisp.fits        10  2.653247e+06  121223.755232  None
# /tmp/myraf_327ydisp.fits        10  3.804117e+06  213363.988438  None
# /tmp/myraf_327ydisp.fits        10  3.865910e+06  214109.969319  None
# /tmp/myraf_327ydisp.fits        10  3.948849e+06  218457.046581  None
# /tmp/myraf_327ydisp.fits        10  4.653852e+06  246785.198561  None
# ...                            ...           ...            ...   ...
# /tmp/myraf_c65fjgp8.fits        10  2.452448e+06  137640.474893  None
# /tmp/myraf_c65fjgp8.fits        10  1.811449e+06  108723.751192  None
# /tmp/myraf_c65fjgp8.fits        10  1.885853e+06  123692.554036  None
# /tmp/myraf_c65fjgp8.fits        10  3.477344e+06  229054.534813  None
# /tmp/myraf_c65fjgp8.fits        10  3.521940e+06  198382.602762  None
#
#                                  snr       mag      merr
# image
# /tmp/myraf_327ydisp.fits   66.330713  8.940556  0.049604
# /tmp/myraf_327ydisp.fits   82.351760  8.549365  0.060894
# /tmp/myraf_327ydisp.fits   75.090073  8.531871  0.060131
# /tmp/myraf_327ydisp.fits  111.505189  8.508824  0.060063
# /tmp/myraf_327ydisp.fits  108.142074  8.330468  0.057573
# ...                              ...       ...       ...
# /tmp/myraf_c65fjgp8.fits   81.115268  9.026000  0.060934
# /tmp/myraf_c65fjgp8.fits  104.442455  9.354935  0.065164
# /tmp/myraf_c65fjgp8.fits   73.603642  9.311230  0.071211
# /tmp/myraf_c65fjgp8.fits   73.311805  8.646881  0.071516
# /tmp/myraf_c65fjgp8.fits   85.519762  8.633045  0.061155
#
# [1560 rows x 12 columns]

# %% [markdown]
# ## photometry
#
# Or one can use both methods at once:

# %%
photometry = fits_array.photometry(sources["xcentroid"].to_list(), sources["ycentroid"].to_list(), 10)
photometry
# Out:
#                          package   xcentroid   ycentroid         ra       dec  \
# image
# /tmp/myraf_327ydisp.fits     sep  460.413271  507.778814  85.270688 -2.441004
# /tmp/myraf_327ydisp.fits     sep  386.810402  127.389405  85.291229 -2.547458
# /tmp/myraf_327ydisp.fits     sep  525.221542  138.399809  85.252400 -2.544334
# /tmp/myraf_327ydisp.fits     sep  859.504395  753.975957  85.158805 -2.371990
# /tmp/myraf_327ydisp.fits     sep  560.489036  865.999199  85.242717 -2.340745
# ...                          ...         ...         ...        ...       ...
# /tmp/myraf_c65fjgp8.fits     phu  276.691617  199.843224  85.347370 -2.552429
# /tmp/myraf_c65fjgp8.fits     phu  170.623468  737.848725  85.377268 -2.401929
# /tmp/myraf_c65fjgp8.fits     phu  513.939993  525.358671  85.280899 -2.461279
# /tmp/myraf_c65fjgp8.fits     phu  646.761183  430.331463  85.243610 -2.487826
# /tmp/myraf_c65fjgp8.fits     phu  482.341496  319.878004  85.289707 -2.518781
#
#                           aperture          flux     flux_error  flag  \
# image
# /tmp/myraf_327ydisp.fits        10  2.650499e+06  121161.453956     0
# /tmp/myraf_327ydisp.fits        10  3.798401e+06  213191.357561     0
# /tmp/myraf_327ydisp.fits        10  3.859562e+06  213931.210210     0
# /tmp/myraf_327ydisp.fits        10  3.949276e+06  218471.016701     0
# /tmp/myraf_327ydisp.fits        10  4.654186e+06  246787.566490     0
# ...                            ...           ...            ...   ...
# /tmp/myraf_c65fjgp8.fits        10  2.452448e+06  137640.474893  None
# /tmp/myraf_c65fjgp8.fits        10  1.811449e+06  108723.751192  None
# /tmp/myraf_c65fjgp8.fits        10  1.885853e+06  123692.554036  None
# /tmp/myraf_c65fjgp8.fits        10  3.477344e+06  229054.534813  None
# /tmp/myraf_c65fjgp8.fits        10  3.521940e+06  198382.602762  None
#
#                                  snr       mag      merr
# image
# /tmp/myraf_327ydisp.fits   66.330713  8.941681  0.049630
# /tmp/myraf_327ydisp.fits   82.351760  8.550998  0.060937
# /tmp/myraf_327ydisp.fits   75.090073  8.533655  0.060179
# /tmp/myraf_327ydisp.fits  111.505189  8.508706  0.060060
# /tmp/myraf_327ydisp.fits  108.142074  8.330391  0.057569
# ...                              ...       ...       ...
# /tmp/myraf_c65fjgp8.fits   81.115268  9.026000  0.060934
# /tmp/myraf_c65fjgp8.fits  104.442455  9.354935  0.065164
# /tmp/myraf_c65fjgp8.fits   73.603642  9.311230  0.071211
# /tmp/myraf_c65fjgp8.fits   73.311805  8.646881  0.071516
# /tmp/myraf_c65fjgp8.fits   85.519762  8.633045  0.061155
#
# [3120 rows x 12 columns]
