# %%
from myraflib import Fits

fits = Fits.sample()
fits
# Out:
# Fits(@: '139967064406960', path:'/tmp/spy_cqkrogc0.fits')

# %% [markdown]
# # Get Header
# ## header
# A `Fits` object can obtain header from a fits file

# %%
headers = fits.header()
headers
# Out:
#                         SIMPLE  BITPIX  NAXIS  NAXIS1  NAXIS2        DATE  \
# image
# /tmp/spy_cqkrogc0.fits    True      16      2     891     893  2014-01-09
#
#                             ORIGIN   SURVEY REGION PLATEID  ...    CD2_2  \
# image                                                       ...
# /tmp/spy_cqkrogc0.fits  STScI/MAST  SERC-ER  ER768    A0JP  ...  0.00028
#
#                        OBJECT  DATAMIN  DATAMAX       OBJCTRA      OBJCTDEC  \
# image
# /tmp/spy_cqkrogc0.fits   data     3759    22918  05 41 06.000  -02 27 30.00
#
#                           OBJCTX    OBJCTY BSCALE  BZERO
# image
# /tmp/spy_cqkrogc0.fits  12682.48  20411.37      1  32768
#
# [1 rows x 162 columns]

# %% [markdown]
# ## pure_header
# `pure_header` returns the header as `astropy` `Header`

# %%
pure_header = fits.pure_header()
pure_header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  891
# NAXIS2  =                  893
# DATE    = '2014-01-09        '  /FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name
# PLATEID = 'A0JP    '           /GSSS: Plate ID
# SCANNUM = '01      '           /GSSS: Scan Number
# DSCNDNUM= '00      '           /GSSS: Descendant Number
# TELESCID=                    4 /GSSS: Telescope ID
# BANDPASS=                   36 /GSSS: Bandpass Code
# COPYRGHT= 'AAO/ROE '           /GSSS: Copyright Holder
# SITELAT =              -31.277 /Observatory: Latitude
# SITELONG=              210.934 /Observatory: Longitude
# TELESCOP= 'UK Schmidt - Doubl' /Observatory: Telescope
# ...

# %% [markdown]
# # Alter Header
#
# ## hedit
# `hedit` can create/update/delete header of a fits object
#
# ### create
# if a none existing card is specified a new header card will be created

# %%
fits.hedit("Test", "MYRaf", "Comment") # Here Test is card, MYRaf is value abd Comment is a comment
fits.pure_header()
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  891
# NAXIS2  =                  893
# DATE    = '2014-01-09        '  /FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name
# PLATEID = 'A0JP    '           /GSSS: Plate ID
# SCANNUM = '01      '           /GSSS: Scan Number
# DSCNDNUM= '00      '           /GSSS: Descendant Number
# TELESCID=                    4 /GSSS: Telescope ID
# BANDPASS=                   36 /GSSS: Bandpass Code
# COPYRGHT= 'AAO/ROE '           /GSSS: Copyright Holder
# SITELAT =              -31.277 /Observatory: Latitude
# SITELONG=              210.934 /Observatory: Longitude
# TELESCOP= 'UK Schmidt - Doubl' /Observatory: Telescope
# ...

# %% [markdown]
# ### update
# if an existing card is specified the header will be updated

# %%
fits.hedit("Test", "MYRaf V3", "Updated Via MYRaf") # Here Test is card, MYRaf is value and Comment is a comment
fits.pure_header()
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  891
# NAXIS2  =                  893
# DATE    = '2014-01-09        '  /FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name
# PLATEID = 'A0JP    '           /GSSS: Plate ID
# SCANNUM = '01      '           /GSSS: Scan Number
# DSCNDNUM= '00      '           /GSSS: Descendant Number
# TELESCID=                    4 /GSSS: Telescope ID
# BANDPASS=                   36 /GSSS: Bandpass Code
# COPYRGHT= 'AAO/ROE '           /GSSS: Copyright Holder
# SITELAT =              -31.277 /Observatory: Latitude
# SITELONG=              210.934 /Observatory: Longitude
# TELESCOP= 'UK Schmidt - Doubl' /Observatory: Telescope
# ...

# %% [markdown]
# You can update an existing or creata a new header with value of another card

# %%
fits.hedit("Test", "BITPIX", "From BITPIX", value_is_key=True) # Here Test is card, BITPIX is cark which its value would be used and Comment is a comment
fits.pure_header()
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  891
# NAXIS2  =                  893
# DATE    = '2014-01-09        '  /FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name
# PLATEID = 'A0JP    '           /GSSS: Plate ID
# SCANNUM = '01      '           /GSSS: Scan Number
# DSCNDNUM= '00      '           /GSSS: Descendant Number
# TELESCID=                    4 /GSSS: Telescope ID
# BANDPASS=                   36 /GSSS: Bandpass Code
# COPYRGHT= 'AAO/ROE '           /GSSS: Copyright Holder
# SITELAT =              -31.277 /Observatory: Latitude
# SITELONG=              210.934 /Observatory: Longitude
# TELESCOP= 'UK Schmidt - Doubl' /Observatory: Telescope
# ...

# %% [markdown]
# ## Delete
# if parameter is true the header card would be deleted no matter other parameters

# %%
fits.hedit("Test", delete=True) # Here Test is card
fits.pure_header()
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  891
# NAXIS2  =                  893
# DATE    = '2014-01-09        '  /FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name
# PLATEID = 'A0JP    '           /GSSS: Plate ID
# SCANNUM = '01      '           /GSSS: Scan Number
# DSCNDNUM= '00      '           /GSSS: Descendant Number
# TELESCID=                    4 /GSSS: Telescope ID
# BANDPASS=                   36 /GSSS: Bandpass Code
# COPYRGHT= 'AAO/ROE '           /GSSS: Copyright Holder
# SITELAT =              -31.277 /Observatory: Latitude
# SITELONG=              210.934 /Observatory: Longitude
# TELESCOP= 'UK Schmidt - Doubl' /Observatory: Telescope
# ...
