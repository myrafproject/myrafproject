# %% [markdown]
# # map_to_sky
# `Fits` can retrieve sources available in the region of the FITS data from Simbad

# %%
from myraflib import Fits
from matplotlib import pyplot as plt
from astropy.visualization import ZScaleInterval
from random import choices

fits = Fits.sample()
fits
# Out:
# Fits(@: '139745637912720', path:'/tmp/myraf_wxwst8xg.fits')

# %%
sky_map = fits.map_to_sky()
sky_map
# Out:
#                            name  \
# 0                   V* V616 Ori
# 1    [KDJ2016] J054113.2-022021
# 2    [KDJ2016] J054129.1-023324
# 3                   [GA90] 3-21
# 4                        HH 248
# ..                          ...
# 178     2MASS J05411138-0233364
# 179       NAME Horsehead Nebula
# 180       ATO J085.1860-02.3789
# 181     2MASS J05403931-0226460
# 182              TYC 4771-896-1
#
#                                                    sky   xcentroid   ycentroid
# 0    <SkyCoord (ICRS): (ra, dec) in deg\n    (85.35...  145.889964  157.340081
# 1    <SkyCoord (ICRS): (ra, dec) in deg\n    (85.30...  336.973430  871.598475
# 2    <SkyCoord (ICRS): (ra, dec) in deg\n    (85.37...  101.417546   94.488984
# 3    <SkyCoord (ICRS): (ra, dec) in deg\n    (85.20...  682.622630  451.548096
# 4    <SkyCoord (ICRS): (ra, dec) in deg\n    (85.36...  140.751036  711.268058
# ..                                                 ...         ...         ...
# 178  <SkyCoord (ICRS): (ra, dec) in deg\n    (85.29...  364.663110   82.104229
# 179  <SkyCoord (ICRS): (ra, dec) in deg\n    (85.24...  548.945023  445.749580
# 180  <SkyCoord (ICRS): (ra, dec) in deg\n    (85.18...  762.476072  729.314910
# 181  <SkyCoord (ICRS): (ra, dec) in deg\n    (85.16...  841.410225  488.907022
# 182  <SkyCoord (ICRS): (ra, dec) in deg\n    (85.32...  276.521801  199.567154
#
# [183 rows x 4 columns]

# %%
plt.imshow(ZScaleInterval()(fits.data()), cmap="gray_r")

for each in choices(sky_map[["name", "xcentroid", "ycentroid"]].values.tolist(), k=10):
    plt.text(each[1], each[2], each[0], color='red', fontsize=8)
    plt.scatter(each[1], each[2], color="red", s=10)

plt.show()
